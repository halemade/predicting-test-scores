# %% [markdown]
# ![Test taking](images/nguyen-dang-hoang-nhu-qDgTQOYk6B8-unsplash.jpg)

# %% [markdown]
# <H1>Predicting Student Test Scores</H1>

# %% [markdown]
# Using a [data set](https://www.kaggle.com/kwadwoofosu/predict-test-scores-of-students) from kaggle, we will predict student test scores using a linear regression model.

# %%
#import the appropriate tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.figure_factory import create_scatterplotmatrix
# %matplotlib inline

# %%
#import the data
df = pd.read_csv('data/test_scores 2.csv')
cols = list(df.columns)

# %%
df.head()
# Out:
#   school school_setting school_type classroom teaching_method  n_student  \
# 0  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4  ANKYI          Urban  Non-public       6OL        Standard       20.0
#
#   student_id  gender             lunch  pretest  posttest
# 0      2FHT3  Female  Does not qualify     62.0      72.0
# 1      3JIVH  Female  Does not qualify     66.0      79.0
# 2      3XOWE    Male  Does not qualify     64.0      76.0
# 3      556O0  Female  Does not qualify     61.0      77.0
# 4      74LOE    Male  Does not qualify     64.0      76.0

# %%
df.shape
# Out:
# (2133, 11)

# %%
df.teaching_method.value_counts()
# Out:
# Standard        1373
# Experimental     760
# Name: teaching_method, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# | Column Header | Description | Notes |
# | :--- | :--- | :--- |
# | **school** | Name of the school the student is enrolled in. | categorical  |
# | **school_setting** | The location of the school | categorical  |
# | **school_type** | The type of school. Either public or non-public | categorical  |
# | **classroom** | The type of classroom | categorical  |
# | **teaching_method** | Teaching methods: Either experimental or Standard | categorical  |
# | **n_student** | Number of students in the class | continuous? |
# | **student_id** | A unique ID for each student | not relevant information |
# | **gender** | The gender of the students: male or female | categorical  |
# | **lunch** | Whether a student qualifies for free/subsidized lunch or not | categorical  |
# | **pretest** | The pretest score of the students out of 100 | might be looking for a measure of improvement |
# | **posttest** | The posttest score of the students out of 100 | which would manifest as a specific score |

# %% [markdown]
# ---

# %%
fig = px.scatter(df, x="pretest", y="posttest", color="lunch",
                 title="Economic Status and Test Scores")

fig.show()
# Out:
# <div>                            <div id="98823169-0fc9-481b-98fd-7ab49154bdc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98823169-0fc9-481b-98fd-7ab49154bdc1")) {                    Plotly.newPlot(                        "98823169-0fc9-481b-98fd-7ab49154bdc1",                        [{"hovertemplate": "lunch=Does not qualify<br>pretest=%{x}<br>posttest=%{y}<extra></extra>", "legendgroup": "Does not qualify", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Does not qualify", "showlegend": true, "type": "scattergl", "x": [62.0, 66.0, 64.0, 61.0, 64.0, 66.0, 63.0, 63.0, 64.0, 61.0, 61.0, 64.0, 66.0, 60.0, 64.0, 64.0, 63.0, 67.0, 63.0, 64.0, 60.0, 60.0, 57.0, 57.0, 58.0, 60.0, 60.0, 54.0, 60.0, 58.0, 66.0, 60.0, 59
# ...

# %%
pd.plotting.scatter_matrix(df,figsize=(len(cols),len(cols)));

# %%
fig = px.scatter_matrix(df,
    dimensions=["n_student", "pretest", "posttest"],
    color="school")
fig.show()
# Out:
# <div>                            <div id="76099e05-bf9a-4a56-a35c-85ced20b15e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76099e05-bf9a-4a56-a35c-85ced20b15e1")) {                    Plotly.newPlot(                        "76099e05-bf9a-4a56-a35c-85ced20b15e1",                        [{"dimensions": [{"axis": {"matches": true}, "label": "n_student", "values": [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0]}, {"axis": {"matches": true}, "label": "pretest", "values": [62.0, 66.0, 64.0, 61.0, 64.0, 66.0, 63.0, 63.0, 64.0, 61.0, 61.0, 64.0, 66.0, 60.0,
# ...

# %%
fig = px.scatter_matrix(df,
    dimensions=["n_student", "pretest", "posttest"],
    color="lunch")
fig.show()
# Out:
# <div>                            <div id="65a18b16-6063-4ac6-969b-fc15b8b8bc5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65a18b16-6063-4ac6-969b-fc15b8b8bc5d")) {                    Plotly.newPlot(                        "65a18b16-6063-4ac6-969b-fc15b8b8bc5d",                        [{"dimensions": [{"axis": {"matches": true}, "label": "n_student", "values": [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 15.0, 15.0, 15.0, 15.0, 15.0, 
# ...

# %%
fig = px.scatter_matrix(df,
    dimensions=["n_student", "pretest", "posttest"],
    color="teaching_method")
fig.show()
# Out:
# <div>                            <div id="b19defe2-e2da-4c80-939c-5a317b79b39d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b19defe2-e2da-4c80-939c-5a317b79b39d")) {                    Plotly.newPlot(                        "b19defe2-e2da-4c80-939c-5a317b79b39d",                        [{"dimensions": [{"axis": {"matches": true}, "label": "n_student", "values": [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.0, 19.0, 19.0, 
# ...

# %%
fig = px.scatter_matrix(df,
    dimensions=["n_student", "pretest", "posttest"],
    color="school_type")
fig.show()
# Out:
# <div>                            <div id="8703ddcc-1171-4436-825f-a232f1fdad88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8703ddcc-1171-4436-825f-a232f1fdad88")) {                    Plotly.newPlot(                        "8703ddcc-1171-4436-825f-a232f1fdad88",                        [{"dimensions": [{"axis": {"matches": true}, "label": "n_student", "values": [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 
# ...

# %%
fig = px.scatter_matrix(df,
    dimensions=["n_student", "pretest", "posttest"],
    color="school_setting")
fig.show()
# Out:
# <div>                            <div id="5b4342b0-c3cb-47e7-9810-cf7a3b794c4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b4342b0-c3cb-47e7-9810-cf7a3b794c4a")) {                    Plotly.newPlot(                        "5b4342b0-c3cb-47e7-9810-cf7a3b794c4a",                        [{"dimensions": [{"axis": {"matches": true}, "label": "n_student", "values": [20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 21.0, 21.0, 21.0, 21.0, 21.0, 
# ...
